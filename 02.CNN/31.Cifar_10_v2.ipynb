# %% [markdown]
# # Cifar-10 이미지 분류 v2

# %% [markdown]
# - 데이터 부풀리기 적용

# %%
import numpy as np
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed
# Out:
# <function tensorflow.python.framework.random_seed.set_seed>

# %% [markdown]
# - 데이터 전처리

# %%
from tensorflow.keras.datasets import cifar10
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 5s 0us/step
# 170508288/170498071 [==============================] - 5s 0us/step

# %%
X_train.shape, X_test.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3))

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,2))
for i in range(10):
    plt.subplot(1,10,i+1)
    plt.imshow(X_train[i]), plt.axis('off')
    plt.title(class_names[y_train[i,0]])
plt.show()

# %%
# X_data: 0~1 사이의 실수(float32)로 변환
X_train = X_train.astype('float32') / 255.
X_test = X_test.astype(np.float32) / 255.

# %%
# y_data: one-hot encoding
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)

# %% [markdown]
# - 모델 정의/설정/학습/평가

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import RMSprop

# %%
model = Sequential([
    Conv2D(32, (3,3), padding='same', input_shape=(32,32,3), activation='relu'),
    Conv2D(32, (3,3), padding='same', activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 7, 7, 64)          0
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 512)               1606144
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,676,842
# Trainable params: 1,676,842
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=RMSprop(learning_rate=0.0001, decay=1e-6),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model_path = 'best-cifar10-v2.h5'
checkpoint = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
early_stop = EarlyStopping(patience=10)

# %% [markdown]
# - 데이터 부풀리기

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, Y_train, Y_valid = train_test_split(
    X_train, Y_train, stratify=Y_train, test_size=0.2, random_state=2022
)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    featurewise_center=False,            # set input mean to 0 over the dataset
    samplewise_center=False,             # set each sample mean to 0
    featurewise_std_normalization=False, # divide inputs by std of dataset
    samplewise_std_normalization=False,  # divide each input by its std
    zca_whitening=False,                 # apply ZCA whitening
    zca_epsilon=1e-06,                   # epsilon for ZCA whitening
    rotation_range=0,                    # randomly rotate images in the range (deg 0 to 180)
    width_shift_range=0.1,               # randomly shift images horizontally
    height_shift_range=0.1,              # randomly shift images vertically
    shear_range=0.,                      # set range for random shear
    zoom_range=0.,                       # set range for random zoom
    channel_shift_range=0.,              # set range for random channel shifts
    fill_mode='nearest',                 # set mode for filling points outside the input boundaries
    cval=0.,                             # value used for fill_mode = "constant"
    horizontal_flip=True,                # randomly flip images
    vertical_flip=False,                 # randomly flip images
    rescale=None,                        # set rescaling factor (applied before any other transformation)
    preprocessing_function=None,         # set function that will be applied on each input
    data_format=None,                    # image data format, either "channels_first" or "channels_last"
    validation_split=0.0                 # fraction of images reserved for validation
)
datagen.fit(X_train)

# %%
hist = model.fit(
    datagen.flow(X_train, Y_train, batch_size=32), 
    validation_data=(X_valid, Y_valid),
    epochs=100, verbose=2,
    callbacks=[checkpoint, early_stop]
)
# Out:
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 1.62716, saving model to best-cifar10-v2.h5
# 1250/1250 - 31s - loss: 1.8880 - accuracy: 0.3047 - val_loss: 1.6272 - val_accuracy: 0.4074 - 31s/epoch - 25ms/step
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 1.62716 to 1.44900, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 1.6115 - accuracy: 0.4127 - val_loss: 1.4490 - val_accuracy: 0.4815 - 20s/epoch - 16ms/step
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 1.44900 to 1.34033, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 1.4884 - accuracy: 0.4594 - val_loss: 1.3403 - val_accuracy: 0.5210 - 20s/epoch - 16ms/step
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 1.34033 to 1.24786, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 1.4009 - accuracy: 0.4949 - val_loss: 1.2479 - val_accuracy: 0.5529 - 20s/epoch - 16ms/step
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 1.24786 to 1.19033, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 1.3335 - accuracy: 0.5240 - val_loss: 1.1903 - val_accuracy: 0.5783 - 20s/epoch - 16ms/step
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 1.19033 to 1.12669, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 1.2815 - accuracy: 0.5438 - val_loss: 1.1267 - val_accuracy: 0.5951 - 20s/epoch - 16ms/step
# Epoch 7/100
#
# Epoch 00007: val_loss did not improve from 1.12669
# 1250/1250 - 20s - loss: 1.2281 - accuracy: 0.5618 - val_loss: 1.1926 - val_accuracy: 0.5780 - 20s/epoch - 16ms/step
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 1.12669 to 1.05506, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 1.1912 - accuracy: 0.5760 - val_loss: 1.0551 - val_accuracy: 0.6266 - 20s/epoch - 16ms/step
# Epoch 9/100
#
# Epoch 00009: val_loss did not improve from 1.05506
# 1250/1250 - 20s - loss: 1.1515 - accuracy: 0.5902 - val_loss: 1.0882 - val_accuracy: 0.6130 - 20s/epoch - 16ms/step
# Epoch 10/100
#
# Epoch 00010: val_loss improved from 1.05506 to 1.02957, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 1.1159 - accuracy: 0.6059 - val_loss: 1.0296 - val_accuracy: 0.6349 - 20s/epoch - 16ms/step
# Epoch 11/100
#
# Epoch 00011: val_loss improved from 1.02957 to 0.96742, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 1.0893 - accuracy: 0.6119 - val_loss: 0.9674 - val_accuracy: 0.6539 - 20s/epoch - 16ms/step
# Epoch 12/100
#
# Epoch 00012: val_loss did not improve from 0.96742
# 1250/1250 - 20s - loss: 1.0619 - accuracy: 0.6260 - val_loss: 1.0079 - val_accuracy: 0.6431 - 20s/epoch - 16ms/step
# Epoch 13/100
#
# Epoch 00013: val_loss improved from 0.96742 to 0.87976, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 1.0415 - accuracy: 0.6323 - val_loss: 0.8798 - val_accuracy: 0.6903 - 20s/epoch - 16ms/step
# Epoch 14/100
#
# Epoch 00014: val_loss did not improve from 0.87976
# 1250/1250 - 20s - loss: 1.0196 - accuracy: 0.6439 - val_loss: 0.8849 - val_accuracy: 0.6889 - 20s/epoch - 16ms/step
# Epoch 15/100
#
# Epoch 00015: val_loss did not improve from 0.87976
# 1250/1250 - 20s - loss: 1.0051 - accuracy: 0.6471 - val_loss: 0.8989 - val_accuracy: 0.6818 - 20s/epoch - 16ms/step
# Epoch 16/100
#
# Epoch 00016: val_loss did not improve from 0.87976
# 1250/1250 - 20s - loss: 0.9869 - accuracy: 0.6538 - val_loss: 0.8912 - val_accuracy: 0.6913 - 20s/epoch - 16ms/step
# Epoch 17/100
#
# Epoch 00017: val_loss improved from 0.87976 to 0.81617, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 0.9705 - accuracy: 0.6584 - val_loss: 0.8162 - val_accuracy: 0.7174 - 20s/epoch - 16ms/step
# Epoch 18/100
#
# Epoch 00018: val_loss did not improve from 0.81617
# 1250/1250 - 20s - loss: 0.9561 - accuracy: 0.6646 - val_loss: 0.8669 - val_accuracy: 0.7005 - 20s/epoch - 16ms/step
# Epoch 19/100
#
# Epoch 00019: val_loss did not improve from 0.81617
# 1250/1250 - 20s - loss: 0.9390 - accuracy: 0.6700 - val_loss: 0.8395 - val_accuracy: 0.7036 - 20s/epoch - 16ms/step
# Epoch 20/100
#
# Epoch 00020: val_loss did not improve from 0.81617
# 1250/1250 - 20s - loss: 0.9299 - accuracy: 0.6765 - val_loss: 0.9147 - val_accuracy: 0.6842 - 20s/epoch - 16ms/step
# Epoch 21/100
#
# Epoch 00021: val_loss did not improve from 0.81617
# 1250/1250 - 20s - loss: 0.9222 - accuracy: 0.6779 - val_loss: 0.8180 - val_accuracy: 0.7161 - 20s/epoch - 16ms/step
# Epoch 22/100
#
# Epoch 00022: val_loss improved from 0.81617 to 0.78867, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 0.9121 - accuracy: 0.6832 - val_loss: 0.7887 - val_accuracy: 0.7304 - 20s/epoch - 16ms/step
# Epoch 23/100
#
# Epoch 00023: val_loss did not improve from 0.78867
# 1250/1250 - 20s - loss: 0.9020 - accuracy: 0.6849 - val_loss: 0.7944 - val_accuracy: 0.7273 - 20s/epoch - 16ms/step
# Epoch 24/100
#
# Epoch 00024: val_loss did not improve from 0.78867
# 1250/1250 - 20s - loss: 0.8989 - accuracy: 0.6898 - val_loss: 0.8071 - val_accuracy: 0.7284 - 20s/epoch - 16ms/step
# Epoch 25/100
#
# Epoch 00025: val_loss did not improve from 0.78867
# 1250/1250 - 20s - loss: 0.8896 - accuracy: 0.6931 - val_loss: 0.8034 - val_accuracy: 0.7241 - 20s/epoch - 16ms/step
# Epoch 26/100
#
# Epoch 00026: val_loss improved from 0.78867 to 0.75388, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 0.8789 - accuracy: 0.6963 - val_loss: 0.7539 - val_accuracy: 0.7372 - 20s/epoch - 16ms/step
# Epoch 27/100
#
# Epoch 00027: val_loss improved from 0.75388 to 0.74313, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 0.8725 - accuracy: 0.6992 - val_loss: 0.7431 - val_accuracy: 0.7446 - 20s/epoch - 16ms/step
# Epoch 28/100
#
# Epoch 00028: val_loss did not improve from 0.74313
# 1250/1250 - 20s - loss: 0.8701 - accuracy: 0.6987 - val_loss: 0.7666 - val_accuracy: 0.7413 - 20s/epoch - 16ms/step
# Epoch 29/100
#
# Epoch 00029: val_loss did not improve from 0.74313
# 1250/1250 - 20s - loss: 0.8725 - accuracy: 0.7009 - val_loss: 0.7635 - val_accuracy: 0.7347 - 20s/epoch - 16ms/step
# Epoch 30/100
#
# Epoch 00030: val_loss did not improve from 0.74313
# 1250/1250 - 20s - loss: 0.8572 - accuracy: 0.7056 - val_loss: 0.7629 - val_accuracy: 0.7372 - 20s/epoch - 16ms/step
# Epoch 31/100
#
# Epoch 00031: val_loss improved from 0.74313 to 0.73375, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 0.8542 - accuracy: 0.7075 - val_loss: 0.7337 - val_accuracy: 0.7477 - 20s/epoch - 16ms/step
# Epoch 32/100
#
# Epoch 00032: val_loss did not improve from 0.73375
# 1250/1250 - 20s - loss: 0.8537 - accuracy: 0.7068 - val_loss: 0.7557 - val_accuracy: 0.7397 - 20s/epoch - 16ms/step
# Epoch 33/100
#
# Epoch 00033: val_loss did not improve from 0.73375
# 1250/1250 - 20s - loss: 0.8449 - accuracy: 0.7101 - val_loss: 0.7434 - val_accuracy: 0.7493 - 20s/epoch - 16ms/step
# Epoch 34/100
#
# Epoch 00034: val_loss did not improve from 0.73375
# 1250/1250 - 20s - loss: 0.8468 - accuracy: 0.7099 - val_loss: 0.7470 - val_accuracy: 0.7420 - 20s/epoch - 16ms/step
# Epoch 35/100
#
# Epoch 00035: val_loss improved from 0.73375 to 0.68972, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 0.8342 - accuracy: 0.7158 - val_loss: 0.6897 - val_accuracy: 0.7636 - 20s/epoch - 16ms/step
# Epoch 36/100
#
# Epoch 00036: val_loss did not improve from 0.68972
# 1250/1250 - 20s - loss: 0.8345 - accuracy: 0.7142 - val_loss: 0.7792 - val_accuracy: 0.7325 - 20s/epoch - 16ms/step
# Epoch 37/100
#
# Epoch 00037: val_loss did not improve from 0.68972
# 1250/1250 - 21s - loss: 0.8324 - accuracy: 0.7169 - val_loss: 0.7139 - val_accuracy: 0.7578 - 21s/epoch - 17ms/step
# Epoch 38/100
#
# Epoch 00038: val_loss did not improve from 0.68972
# 1250/1250 - 20s - loss: 0.8290 - accuracy: 0.7162 - val_loss: 0.7563 - val_accuracy: 0.7416 - 20s/epoch - 16ms/step
# Epoch 39/100
#
# Epoch 00039: val_loss did not improve from 0.68972
# 1250/1250 - 20s - loss: 0.8208 - accuracy: 0.7174 - val_loss: 0.7382 - val_accuracy: 0.7476 - 20s/epoch - 16ms/step
# Epoch 40/100
#
# Epoch 00040: val_loss did not improve from 0.68972
# 1250/1250 - 20s - loss: 0.8250 - accuracy: 0.7175 - val_loss: 0.7261 - val_accuracy: 0.7580 - 20s/epoch - 16ms/step
# Epoch 41/100
#
# Epoch 00041: val_loss did not improve from 0.68972
# 1250/1250 - 20s - loss: 0.8258 - accuracy: 0.7206 - val_loss: 0.7100 - val_accuracy: 0.7574 - 20s/epoch - 16ms/step
# Epoch 42/100
#
# Epoch 00042: val_loss did not improve from 0.68972
# 1250/1250 - 20s - loss: 0.8259 - accuracy: 0.7175 - val_loss: 0.7276 - val_accuracy: 0.7523 - 20s/epoch - 16ms/step
# Epoch 43/100
#
# Epoch 00043: val_loss did not improve from 0.68972
# 1250/1250 - 20s - loss: 0.8222 - accuracy: 0.7176 - val_loss: 0.7399 - val_accuracy: 0.7476 - 20s/epoch - 16ms/step
# Epoch 44/100
#
# Epoch 00044: val_loss did not improve from 0.68972
# 1250/1250 - 20s - loss: 0.8173 - accuracy: 0.7216 - val_loss: 0.7457 - val_accuracy: 0.7470 - 20s/epoch - 16ms/step
# Epoch 45/100
#
# Epoch 00045: val_loss did not improve from 0.68972
# 1250/1250 - 20s - loss: 0.8138 - accuracy: 0.7218 - val_loss: 0.7723 - val_accuracy: 0.7437 - 20s/epoch - 16ms/step

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.7080 - accuracy: 0.7642
# [0.7079960703849792, 0.76419997215271]

# %% [markdown]
# - 학습과정 시각화

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.show()
