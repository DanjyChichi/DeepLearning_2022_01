# %% [markdown]
# # Cifar-10 이미지 분류 v1

# %%
import numpy as np
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed
# Out:
# <function tensorflow.python.framework.random_seed.set_seed>

# %% [markdown]
# - 데이터 전처리

# %%
from tensorflow.keras.datasets import cifar10
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 3s 0us/step
# 170508288/170498071 [==============================] - 3s 0us/step

# %%
X_train.shape, X_test.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3))

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,2))
for i in range(10):
    plt.subplot(1,10,i+1)
    plt.imshow(X_train[i]), plt.axis('off')
    plt.title(class_names[y_train[i,0]])
plt.show()

# %%
# X_data: 0~1 사이의 실수(float32)로 변환
X_train = X_train.astype('float32') / 255.
X_test = X_test.astype(np.float32) / 255.

# %%
# y_data: one-hot encoding
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)

# %% [markdown]
# - 모델 정의/설정/학습/평가

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import RMSprop

# %%
model = Sequential([
    Conv2D(32, (3,3), padding='same', input_shape=(32,32,3), activation='relu'),
    Conv2D(32, (3,3), padding='same', activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 7, 7, 64)          0
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 512)               1606144
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,676,842
# Trainable params: 1,676,842
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=RMSprop(learning_rate=0.0001, decay=1e-6),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model_path = 'best-cifar10-v1.h5'
checkpoint = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
early_stop = EarlyStopping(patience=10)

# %%
hist = model.fit(
    X_train, Y_train, validation_split=0.2,
    epochs=100, batch_size=32, verbose=2,
    callbacks=[checkpoint, early_stop]
)
# Out:
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 1.56615, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 1.8495 - accuracy: 0.3284 - val_loss: 1.5662 - val_accuracy: 0.4404 - 22s/epoch - 17ms/step
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 1.56615 to 1.36844, saving model to best-cifar10-v1.h5
# 1250/1250 - 7s - loss: 1.5104 - accuracy: 0.4542 - val_loss: 1.3684 - val_accuracy: 0.5112 - 7s/epoch - 5ms/step
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 1.36844 to 1.28366, saving model to best-cifar10-v1.h5
# 1250/1250 - 7s - loss: 1.3611 - accuracy: 0.5126 - val_loss: 1.2837 - val_accuracy: 0.5440 - 7s/epoch - 5ms/step
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 1.28366 to 1.17619, saving model to best-cifar10-v1.h5
# 1250/1250 - 6s - loss: 1.2532 - accuracy: 0.5574 - val_loss: 1.1762 - val_accuracy: 0.5869 - 6s/epoch - 5ms/step
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 1.17619 to 1.07405, saving model to best-cifar10-v1.h5
# 1250/1250 - 7s - loss: 1.1701 - accuracy: 0.5865 - val_loss: 1.0740 - val_accuracy: 0.6292 - 7s/epoch - 5ms/step
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 1.07405 to 1.00734, saving model to best-cifar10-v1.h5
# 1250/1250 - 7s - loss: 1.1026 - accuracy: 0.6122 - val_loss: 1.0073 - val_accuracy: 0.6521 - 7s/epoch - 5ms/step
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 1.00734 to 0.96982, saving model to best-cifar10-v1.h5
# 1250/1250 - 7s - loss: 1.0434 - accuracy: 0.6362 - val_loss: 0.9698 - val_accuracy: 0.6688 - 7s/epoch - 5ms/step
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 0.96982 to 0.95437, saving model to best-cifar10-v1.h5
# 1250/1250 - 7s - loss: 0.9932 - accuracy: 0.6513 - val_loss: 0.9544 - val_accuracy: 0.6665 - 7s/epoch - 5ms/step
# Epoch 9/100
#
# Epoch 00009: val_loss improved from 0.95437 to 0.93433, saving model to best-cifar10-v1.h5
# 1250/1250 - 6s - loss: 0.9492 - accuracy: 0.6663 - val_loss: 0.9343 - val_accuracy: 0.6697 - 6s/epoch - 5ms/step
# Epoch 10/100
#
# Epoch 00010: val_loss improved from 0.93433 to 0.85558, saving model to best-cifar10-v1.h5
# 1250/1250 - 7s - loss: 0.9184 - accuracy: 0.6771 - val_loss: 0.8556 - val_accuracy: 0.6997 - 7s/epoch - 5ms/step
# Epoch 11/100
#
# Epoch 00011: val_loss improved from 0.85558 to 0.83501, saving model to best-cifar10-v1.h5
# 1250/1250 - 7s - loss: 0.8898 - accuracy: 0.6886 - val_loss: 0.8350 - val_accuracy: 0.7064 - 7s/epoch - 5ms/step
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 0.83501 to 0.81554, saving model to best-cifar10-v1.h5
# 1250/1250 - 6s - loss: 0.8587 - accuracy: 0.7016 - val_loss: 0.8155 - val_accuracy: 0.7115 - 6s/epoch - 5ms/step
# Epoch 13/100
#
# Epoch 00013: val_loss did not improve from 0.81554
# 1250/1250 - 7s - loss: 0.8374 - accuracy: 0.7096 - val_loss: 0.8244 - val_accuracy: 0.7120 - 7s/epoch - 5ms/step
# Epoch 14/100
#
# Epoch 00014: val_loss improved from 0.81554 to 0.79475, saving model to best-cifar10-v1.h5
# 1250/1250 - 7s - loss: 0.8157 - accuracy: 0.7169 - val_loss: 0.7947 - val_accuracy: 0.7237 - 7s/epoch - 5ms/step
# Epoch 15/100
#
# Epoch 00015: val_loss improved from 0.79475 to 0.77753, saving model to best-cifar10-v1.h5
# 1250/1250 - 6s - loss: 0.7955 - accuracy: 0.7211 - val_loss: 0.7775 - val_accuracy: 0.7294 - 6s/epoch - 5ms/step
# Epoch 16/100
#
# Epoch 00016: val_loss did not improve from 0.77753
# 1250/1250 - 6s - loss: 0.7821 - accuracy: 0.7266 - val_loss: 0.7819 - val_accuracy: 0.7302 - 6s/epoch - 5ms/step
# Epoch 17/100
#
# Epoch 00017: val_loss improved from 0.77753 to 0.73761, saving model to best-cifar10-v1.h5
# 1250/1250 - 7s - loss: 0.7649 - accuracy: 0.7368 - val_loss: 0.7376 - val_accuracy: 0.7486 - 7s/epoch - 5ms/step
# Epoch 18/100
#
# Epoch 00018: val_loss did not improve from 0.73761
# 1250/1250 - 7s - loss: 0.7563 - accuracy: 0.7406 - val_loss: 0.7525 - val_accuracy: 0.7408 - 7s/epoch - 5ms/step
# Epoch 19/100
#
# Epoch 00019: val_loss improved from 0.73761 to 0.72631, saving model to best-cifar10-v1.h5
# 1250/1250 - 7s - loss: 0.7378 - accuracy: 0.7447 - val_loss: 0.7263 - val_accuracy: 0.7532 - 7s/epoch - 5ms/step
# Epoch 20/100
#
# Epoch 00020: val_loss improved from 0.72631 to 0.71775, saving model to best-cifar10-v1.h5
# 1250/1250 - 6s - loss: 0.7318 - accuracy: 0.7466 - val_loss: 0.7178 - val_accuracy: 0.7546 - 6s/epoch - 5ms/step
# Epoch 21/100
#
# Epoch 00021: val_loss improved from 0.71775 to 0.69798, saving model to best-cifar10-v1.h5
# 1250/1250 - 7s - loss: 0.7164 - accuracy: 0.7527 - val_loss: 0.6980 - val_accuracy: 0.7617 - 7s/epoch - 5ms/step
# Epoch 22/100
#
# Epoch 00022: val_loss did not improve from 0.69798
# 1250/1250 - 7s - loss: 0.7169 - accuracy: 0.7525 - val_loss: 0.7174 - val_accuracy: 0.7565 - 7s/epoch - 5ms/step
# Epoch 23/100
#
# Epoch 00023: val_loss improved from 0.69798 to 0.68870, saving model to best-cifar10-v1.h5
# 1250/1250 - 6s - loss: 0.7076 - accuracy: 0.7564 - val_loss: 0.6887 - val_accuracy: 0.7664 - 6s/epoch - 5ms/step
# Epoch 24/100
#
# Epoch 00024: val_loss did not improve from 0.68870
# 1250/1250 - 6s - loss: 0.7006 - accuracy: 0.7591 - val_loss: 0.6979 - val_accuracy: 0.7643 - 6s/epoch - 5ms/step
# Epoch 25/100
#
# Epoch 00025: val_loss improved from 0.68870 to 0.68651, saving model to best-cifar10-v1.h5
# 1250/1250 - 7s - loss: 0.6897 - accuracy: 0.7628 - val_loss: 0.6865 - val_accuracy: 0.7697 - 7s/epoch - 5ms/step
# Epoch 26/100
#
# Epoch 00026: val_loss did not improve from 0.68651
# 1250/1250 - 6s - loss: 0.6868 - accuracy: 0.7645 - val_loss: 0.6917 - val_accuracy: 0.7665 - 6s/epoch - 5ms/step
# Epoch 27/100
#
# Epoch 00027: val_loss did not improve from 0.68651
# 1250/1250 - 7s - loss: 0.6859 - accuracy: 0.7645 - val_loss: 0.6941 - val_accuracy: 0.7650 - 7s/epoch - 5ms/step
# Epoch 28/100
#
# Epoch 00028: val_loss improved from 0.68651 to 0.67659, saving model to best-cifar10-v1.h5
# 1250/1250 - 7s - loss: 0.6770 - accuracy: 0.7675 - val_loss: 0.6766 - val_accuracy: 0.7711 - 7s/epoch - 5ms/step
# Epoch 29/100
#
# Epoch 00029: val_loss did not improve from 0.67659
# 1250/1250 - 6s - loss: 0.6724 - accuracy: 0.7684 - val_loss: 0.6773 - val_accuracy: 0.7654 - 6s/epoch - 5ms/step
# Epoch 30/100
#
# Epoch 00030: val_loss did not improve from 0.67659
# 1250/1250 - 6s - loss: 0.6683 - accuracy: 0.7706 - val_loss: 0.6838 - val_accuracy: 0.7682 - 6s/epoch - 5ms/step
# Epoch 31/100
#
# Epoch 00031: val_loss did not improve from 0.67659
# 1250/1250 - 6s - loss: 0.6703 - accuracy: 0.7735 - val_loss: 0.6899 - val_accuracy: 0.7668 - 6s/epoch - 5ms/step
# Epoch 32/100
#
# Epoch 00032: val_loss did not improve from 0.67659
# 1250/1250 - 6s - loss: 0.6653 - accuracy: 0.7738 - val_loss: 0.7026 - val_accuracy: 0.7654 - 6s/epoch - 5ms/step
# Epoch 33/100
#
# Epoch 00033: val_loss did not improve from 0.67659
# 1250/1250 - 7s - loss: 0.6599 - accuracy: 0.7763 - val_loss: 0.6942 - val_accuracy: 0.7737 - 7s/epoch - 5ms/step
# Epoch 34/100
#
# Epoch 00034: val_loss improved from 0.67659 to 0.66843, saving model to best-cifar10-v1.h5
# 1250/1250 - 6s - loss: 0.6584 - accuracy: 0.7758 - val_loss: 0.6684 - val_accuracy: 0.7750 - 6s/epoch - 5ms/step
# Epoch 35/100
#
# Epoch 00035: val_loss did not improve from 0.66843
# 1250/1250 - 6s - loss: 0.6569 - accuracy: 0.7765 - val_loss: 0.6907 - val_accuracy: 0.7778 - 6s/epoch - 5ms/step
# Epoch 36/100
#
# Epoch 00036: val_loss improved from 0.66843 to 0.66723, saving model to best-cifar10-v1.h5
# 1250/1250 - 6s - loss: 0.6555 - accuracy: 0.7772 - val_loss: 0.6672 - val_accuracy: 0.7788 - 6s/epoch - 5ms/step
# Epoch 37/100
#
# Epoch 00037: val_loss did not improve from 0.66723
# 1250/1250 - 7s - loss: 0.6484 - accuracy: 0.7800 - val_loss: 0.6710 - val_accuracy: 0.7756 - 7s/epoch - 5ms/step
# Epoch 38/100
#
# Epoch 00038: val_loss improved from 0.66723 to 0.66245, saving model to best-cifar10-v1.h5
# 1250/1250 - 7s - loss: 0.6431 - accuracy: 0.7832 - val_loss: 0.6624 - val_accuracy: 0.7864 - 7s/epoch - 5ms/step
# Epoch 39/100
#
# Epoch 00039: val_loss did not improve from 0.66245
# 1250/1250 - 6s - loss: 0.6428 - accuracy: 0.7840 - val_loss: 0.6978 - val_accuracy: 0.7734 - 6s/epoch - 5ms/step
# Epoch 40/100
#
# Epoch 00040: val_loss did not improve from 0.66245
# 1250/1250 - 6s - loss: 0.6466 - accuracy: 0.7818 - val_loss: 0.6690 - val_accuracy: 0.7826 - 6s/epoch - 5ms/step
# Epoch 41/100
#
# Epoch 00041: val_loss did not improve from 0.66245
# 1250/1250 - 7s - loss: 0.6414 - accuracy: 0.7851 - val_loss: 0.6637 - val_accuracy: 0.7808 - 7s/epoch - 5ms/step
# Epoch 42/100
#
# Epoch 00042: val_loss did not improve from 0.66245
# 1250/1250 - 7s - loss: 0.6372 - accuracy: 0.7848 - val_loss: 0.6860 - val_accuracy: 0.7749 - 7s/epoch - 5ms/step
# Epoch 43/100
#
# Epoch 00043: val_loss did not improve from 0.66245
# 1250/1250 - 6s - loss: 0.6328 - accuracy: 0.7864 - val_loss: 0.6900 - val_accuracy: 0.7771 - 6s/epoch - 5ms/step
# Epoch 44/100
#
# Epoch 00044: val_loss did not improve from 0.66245
# 1250/1250 - 7s - loss: 0.6330 - accuracy: 0.7882 - val_loss: 0.6797 - val_accuracy: 0.7793 - 7s/epoch - 5ms/step
# Epoch 45/100
#
# Epoch 00045: val_loss improved from 0.66245 to 0.64024, saving model to best-cifar10-v1.h5
# 1250/1250 - 7s - loss: 0.6260 - accuracy: 0.7887 - val_loss: 0.6402 - val_accuracy: 0.7911 - 7s/epoch - 5ms/step
# Epoch 46/100
#
# Epoch 00046: val_loss did not improve from 0.64024
# 1250/1250 - 7s - loss: 0.6268 - accuracy: 0.7903 - val_loss: 0.6770 - val_accuracy: 0.7721 - 7s/epoch - 5ms/step
# Epoch 47/100
#
# Epoch 00047: val_loss did not improve from 0.64024
# 1250/1250 - 7s - loss: 0.6282 - accuracy: 0.7904 - val_loss: 0.7166 - val_accuracy: 0.7616 - 7s/epoch - 5ms/step
# Epoch 48/100
#
# Epoch 00048: val_loss did not improve from 0.64024
# 1250/1250 - 7s - loss: 0.6252 - accuracy: 0.7893 - val_loss: 0.6762 - val_accuracy: 0.7771 - 7s/epoch - 5ms/step
# Epoch 49/100
#
# Epoch 00049: val_loss did not improve from 0.64024
# 1250/1250 - 7s - loss: 0.6278 - accuracy: 0.7880 - val_loss: 0.6443 - val_accuracy: 0.7902 - 7s/epoch - 5ms/step
# Epoch 50/100
#
# Epoch 00050: val_loss did not improve from 0.64024
# 1250/1250 - 7s - loss: 0.6271 - accuracy: 0.7903 - val_loss: 0.6477 - val_accuracy: 0.7857 - 7s/epoch - 5ms/step
# Epoch 51/100
#
# Epoch 00051: val_loss did not improve from 0.64024
# 1250/1250 - 6s - loss: 0.6227 - accuracy: 0.7910 - val_loss: 0.6689 - val_accuracy: 0.7810 - 6s/epoch - 5ms/step
# Epoch 52/100
#
# Epoch 00052: val_loss did not improve from 0.64024
# 1250/1250 - 6s - loss: 0.6200 - accuracy: 0.7918 - val_loss: 0.6638 - val_accuracy: 0.7828 - 6s/epoch - 5ms/step
# Epoch 53/100
#
# Epoch 00053: val_loss did not improve from 0.64024
# 1250/1250 - 7s - loss: 0.6236 - accuracy: 0.7916 - val_loss: 0.6581 - val_accuracy: 0.7823 - 7s/epoch - 5ms/step
# Epoch 54/100
#
# Epoch 00054: val_loss did not improve from 0.64024
# 1250/1250 - 6s - loss: 0.6181 - accuracy: 0.7942 - val_loss: 0.6463 - val_accuracy: 0.7875 - 6s/epoch - 5ms/step
# Epoch 55/100
#
# Epoch 00055: val_loss did not improve from 0.64024
# 1250/1250 - 7s - loss: 0.6143 - accuracy: 0.7943 - val_loss: 0.6553 - val_accuracy: 0.7825 - 7s/epoch - 5ms/step

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6431 - accuracy: 0.7836
# [0.6431016325950623, 0.7835999727249146]

# %% [markdown]
# - 학습과정 시각화

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.show()
